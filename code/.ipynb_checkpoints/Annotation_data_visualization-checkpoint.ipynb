# %% [markdown]
# <a href="https://colab.research.google.com/github/MagicShow1999/NLP-final-project/blob/master/Annotation_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import logging
import pandas as pd
import numpy as np
from numpy import random
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
import psycopg2

# %%
df = pd.read_csv('ydata-ynacc-v1_0_expert_annotations.tsv',sep='\t')

df.dropna(inplace = True)
df.drop_duplicates(inplace= True)
df.head()
# Out:
#        sdid  commentindex  ...               intendedaudience  persuasiveness
# 4    135929             1  ...  Reply to a specific commenter  Not persuasive
# 90   136165             2  ...  Reply to a specific commenter  Not persuasive
# 131  135954             3  ...  Reply to a specific commenter  Not persuasive
# 132  135954             2  ...  Reply to a specific commenter  Not persuasive
# 139  128778             3  ...  Reply to a specific commenter  Not persuasive
#
# [5 rows x 20 columns]

# %%
df.columns.values
# Out:
# array(['sdid', 'commentindex', 'headline', 'url', 'guid', 'commentid',
#        'timestamp', 'thumbs-up', 'thumbs-down', 'text', 'parentid',
#        'constructiveclass', 'sd_agreement', 'sd_type', 'sentiment',
#        'tone', 'commentagreement', 'topic', 'intendedaudience',
#        'persuasiveness'], dtype=object)

# %%
print(df['constructiveclass'].unique())
print(df['sd_agreement'].unique())
print(df['sentiment'].unique())
print(df['intendedaudience'].unique())
print(df['persuasiveness'].unique())
# Out:
# ['Not constructive' 'Constructive']
# ['Agreement throughout' 'Continual disagreement'
#  'Initial agreement leading to disagreement'
#  'Initial disagreement converging to agreement']
# ['neutral' 'negative' 'positive' 'mixed']
# ['Reply to a specific commenter' 'Broadcast message / general audience']
# ['Not persuasive' 'Persuasive']
# ['Agreement with commenter' 'Disagreement with commenter'
#  'Adjunct opinion' 'Agreement with commenter,Adjunct opinion'
#  'Agreement with commenter,Disagreement with commenter'
#  'Disagreement with commenter,NA' 'Agreement with commenter,NA'
#  'Disagreement with commenter,Adjunct opinion'
#  'Disagreement with commenter,Adjunct opinion,NA' 'Adjunct opinion,NA']

# %%
ca_set = set()
for ca in df['commentagreement']:
  for word in ca.split(','):
    if word != 'NA':
      ca_set.add(word)
ca_set
# Out:
# {'Adjunct opinion', 'Agreement with commenter', 'Disagreement with commenter'}

# %%
tone_set = set()
for tone in df['tone']:
  for word in tone.split(','):
    if word != 'NA':
      tone_set.add(word)
tone_set
# Out:
# {'Controversial', 'Funny', 'Informative', 'Mean', 'Sarcastic', 'Sympathetic'}

# %%
sd_type_set = set()
for t in df['sd_type']:
  for word in t.split(','):
    if word != 'NA':
      sd_type_set.add(word)
sd_type_set
# Out:
# {'Argumentative (back and forth)',
#  'Flamewar (insulting)',
#  'Off-topic/digression',
#  'Personal stories',
#  'Positive/respectful',
#  'Snarky/humorous'}

# %%
topic_set = set()
for topic in df['topic']:
  for word in topic.split(','):
    if word != 'NA':
      topic_set.add(word)
topic_set
# Out:
# {'Off-topic with article', 'Off-topic with conversation', 'Personal story'}

# %%
np.array(df['thumbs-up']).astype(np.float64).max()
# Out:
# 44.0

# %%
np.array(df['thumbs-down']).astype(np.float64).max()
# Out:
# 64.0

# %%
gcp = df[['text','constructiveclass','persuasiveness','sentiment']]
gcp = gcp.drop_duplicates()

# %%
gcp.describe()
# Out:
#                                                      text  ... sentiment
# count                                                1519  ...      1519
# unique                                               1259  ...         4
# top     Ya, I always wonder why the conservatives are ...  ...  negative
# freq                                                    3  ...       968
#
# [4 rows x 4 columns]

# %%
from sklearn.metrics import matthews_corrcoef
tone_dict = {}
for i in tone_set:
  tone_dict[i] = []
tone_dict
type_dict = {}
for i in sd_type_set:
  type_dict[i] = []
type_dict
topic_dict = {}
for i in topic_set:
  topic_dict[i] = []
topic_dict
ca_dict = {}
for i in ca_set:
  ca_dict[i] = []
ca_dict
# Out:
# {'Adjunct opinion': [],
#  'Agreement with commenter': [],
#  'Disagreement with commenter': []}

# %%
target = df[['constructiveclass','persuasiveness','sentiment','sd_agreement','intendedaudience']]


for t in df['tone']:
  for s in tone_set:
    if s in t:
      tone_dict[s].append(1)
    else:
      tone_dict[s].append(0)
for k,v in tone_dict.items():
  target[k] = v

for t in df['sd_type']:
  for s in sd_type_set:
    if s in t:
      type_dict[s].append(1)
    else:
      type_dict[s].append(0)
for k,v in type_dict.items():
  target[k] = v

for t in df['commentagreement']:
  for s in ca_set:
    if s in t:
      ca_dict[s].append(1)
    else:
      ca_dict[s].append(0)
for k,v in ca_dict.items():
  target[k] = v

for t in df['topic']:
  for s in topic_set:
    if s in t:
      topic_dict[s].append(1)
    else:
      topic_dict[s].append(0)
for k,v in topic_dict.items():
  target[k] = v
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
target.sample(5)
# Out:
#       constructiveclass  ... Off-topic with conversation
# 509    Not constructive  ...                           1
# 15543  Not constructive  ...                           0
# 13866      Constructive  ...                           0
# 18188  Not constructive  ...                           0
# 5382   Not constructive  ...                           0
#
# [5 rows x 23 columns]

# %%
dumm = pd.get_dummies(target)

dumm.head()
# Out:
#      Informative  ...  intendedaudience_Reply to a specific commenter
# 4              0  ...                                               1
# 90             0  ...                                               1
# 131            0  ...                                               1
# 132            0  ...                                               1
# 139            0  ...                                               1
#
# [5 rows x 32 columns]

# %%
#defining popularity
focus_popularity = df['thumbs-up'] + df['thumbs-down']
popularity = [1 if x > np.median(focus_popularity) else 0 for x in focus_popularity]
dumm['popularity'] = popularity
dumm['Likeness'] = df['thumbs-up'] - df['thumbs-down']
dumm['Likeness'] = [1  if x > 0 else 0 for x in dumm['Likeness']]
dumm['Dis_Likeness'] = [1  if x <= 0 else 0 for x in dumm['Likeness']]
dumm.head()
# Out:
#      Informative  Funny  Sympathetic  ...  popularity  Likeness  Dis_Likeness
# 4              0      0            0  ...           1         1             0
# 90             0      0            0  ...           1         0             1
# 131            0      0            0  ...           0         0             1
# 132            0      0            0  ...           0         0             1
# 139            0      0            0  ...           0         1             0
#
# [5 rows x 35 columns]

# %%
dumm.columns = ['Informative','Funny','Sympathetic','Mean','Sarcastic','Controversial',
                'Personal stories','Off-topic/digression','Snarky/humorous','Flamewar_insulting','Respectful','Argumentative_(back and forth)',
                'Agree with commenter','Disagree with commenter','Adjunct opinion',
                'Off-topic with article','Personal story','Off-topic with conversation',
                '(ERIC Thread)Constructive','(nonERIC Thread)Not_constructive',
                'Not_persuasive','Persuasive',
                'mixed','negative','neutral','positive',
                'Agreement_throughout','Continual_disagreement','Initial_agreement_leading_to_disagreement','Initial_disagreement_converging_to_agreement',
                'Broadcast message / general audience','Reply_to_specific',
                'Popularity','Likeness','Dis_Likeness']
dumm = dumm[['(ERIC Thread)Constructive','(nonERIC Thread)Not_constructive',
                       'Personal stories','Off-topic/digression','Snarky/humorous','Flamewar_insulting','Respectful','Argumentative_(back and forth)',
                       'Agreement_throughout','Continual_disagreement','Initial_agreement_leading_to_disagreement','Initial_disagreement_converging_to_agreement',
                       'Agree with commenter','Disagree with commenter','Adjunct opinion',
                'Off-topic with article','Personal story','Off-topic with conversation',
                 'Not_persuasive','Persuasive',
                'mixed','negative','neutral','positive',
                'Broadcast message / general audience','Reply_to_specific',
                'Popularity','Likeness','Dis_Likeness'
                       ]]

dumm.head(5)
# Out:
#      (ERIC Thread)Constructive  ...  Dis_Likeness
# 4                            0  ...             0
# 90                           0  ...             1
# 131                          0  ...             1
# 132                          0  ...             1
# 139                          0  ...             0
#
# [5 rows x 29 columns]

# %%
dumm_corr = dumm.corr(method = 'pearson')

dumm_corr.style.background_gradient(cmap=sns.diverging_palette(220, 10, as_cmap=True)).set_precision(5)
# Out:
# <style  type="text/css" >
#     #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col0 {
#             background-color:  #da3b46;
#             color:  #f1f1f1;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col1 {
#             background-color:  #3f7f93;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col2 {
#             background-color:  #b2cdd6;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col3 {
#             background-color:  #548e9f;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col4 {
#             background-color:  #428195;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col5 {
#             background-color:  #3f7f93;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col6 {
#             background-color:  #cbdee4;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col7 {
#             background-color:  #ddeaee;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col8 {
#             background-color:  #ccdfe4;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col9 {
#             background-color:  #aac8d1;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col10 {
#             background-color:  #d3e3e8;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col11 {
#             background-color:  #d1e2e7;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col12 {
#             background-color:  #d3e3e8;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col13 {
#             background-color:  #b6d0d7;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col14 {
#             background-color:  #d3e3e8;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col15 {
#             background-color:  #c7dbe1;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col16 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col17 {
#             background-color:  #8eb4c0;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col18 {
#             background-color:  #d4e4e9;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col19 {
#             background-color:  #f6d0d3;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col20 {
#             background-color:  #e2eef1;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col21 {
#             background-color:  #9fc0ca;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col22 {
#             background-color:  #cbdee4;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col23 {
#             background-color:  #b2cdd6;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col24 {
#             background-color:  #fae7e8;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col25 {
#             background-color:  #eaf3f6;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col26 {
#             background-color:  #6d9ead;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col27 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row0_col28 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col0 {
#             background-color:  #3f7f93;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col1 {
#             background-color:  #da3b46;
#             color:  #f1f1f1;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col2 {
#             background-color:  #6599a9;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col3 {
#             background-color:  #b2cdd6;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col4 {
#             background-color:  #92b7c3;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col5 {
#             background-color:  #f9dddf;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col6 {
#             background-color:  #6196a7;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col7 {
#             background-color:  #518c9e;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col8 {
#             background-color:  #bfd6dd;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col9 {
#             background-color:  #e2eef1;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col10 {
#             background-color:  #acc9d2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col11 {
#             background-color:  #9fc0ca;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col12 {
#             background-color:  #c3d8df;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col13 {
#             background-color:  #dfecef;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col14 {
#             background-color:  #adcad2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col15 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col16 {
#             background-color:  #c4d9e0;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col17 {
#             background-color:  #a8c6cf;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col18 {
#             background-color:  #f6d0d3;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col19 {
#             background-color:  #d4e4e9;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col20 {
#             background-color:  #a9c7d0;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col21 {
#             background-color:  #edf5f7;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col22 {
#             background-color:  #adcad2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col23 {
#             background-color:  #8fb5c1;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col24 {
#             background-color:  #eaf3f6;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col25 {
#             background-color:  #fae7e8;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col26 {
#             background-color:  #689bab;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col27 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row1_col28 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row2_col0 {
#             background-color:  #f8d8db;
#             color:  #000000;
#         }    #T_53a3cb8e_939d_11ea_b13e_0242ac1c0002row2_col1 {
#             background-color:  #dc

# %%
con_corr = dumm_corr[['(ERIC Thread)Constructive','(nonERIC Thread)Not_constructive']].drop(['(ERIC Thread)Constructive','(nonERIC Thread)Not_constructive'], axis=0)

# %%
sns.palplot(sns.diverging_palette(220, 10, n=7))

con_corr.style.background_gradient(cmap=sns.diverging_palette(220, 10, as_cmap=True)).set_properties(**{'font-size': '0pt'})
# Out:
# <style  type="text/css" >
#     #T_57b19b16_939d_11ea_b13e_0242ac1c0002row0_col0 {
#             background-color:  #e77e86;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row0_col1 {
#             background-color:  #82adba;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row1_col0 {
#             background-color:  #bfd6dd;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row1_col1 {
#             background-color:  #f2bcc0;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row2_col0 {
#             background-color:  #d4e4e9;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row2_col1 {
#             background-color:  #f6d0d3;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row3_col0 {
#             background-color:  #3f7f93;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row3_col1 {
#             background-color:  #da3b46;
#             color:  #f1f1f1;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row4_col0 {
#             background-color:  #e15e68;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row4_col1 {
#             background-color:  #6397a7;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row5_col0 {
#             background-color:  #da3b46;
#             color:  #f1f1f1;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row5_col1 {
#             background-color:  #3f7f93;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row6_col0 {
#             background-color:  #f3bdc1;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row6_col1 {
#             background-color:  #c1d7de;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row7_col0 {
#             background-color:  #d4e4e9;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row7_col1 {
#             background-color:  #f6d0d3;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row8_col0 {
#             background-color:  #ec9ca2;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row8_col1 {
#             background-color:  #a0c1cb;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row9_col0 {
#             background-color:  #ea9097;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row9_col1 {
#             background-color:  #94b9c4;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row10_col0 {
#             background-color:  #f1b6ba;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row10_col1 {
#             background-color:  #bad2da;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row11_col0 {
#             background-color:  #e8f1f4;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row11_col1 {
#             background-color:  #fae4e6;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row12_col0 {
#             background-color:  #ed9da3;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row12_col1 {
#             background-color:  #a1c2cc;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row13_col0 {
#             background-color:  #d5e5ea;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row13_col1 {
#             background-color:  #f6d2d4;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row14_col0 {
#             background-color:  #e67c84;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row14_col1 {
#             background-color:  #81acb9;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row15_col0 {
#             background-color:  #fae5e7;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row15_col1 {
#             background-color:  #e9f2f5;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row16_col0 {
#             background-color:  #b1ccd5;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row16_col1 {
#             background-color:  #f0adb2;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row17_col0 {
#             background-color:  #e1616b;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row17_col1 {
#             background-color:  #6599a9;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row18_col0 {
#             background-color:  #e8858d;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row18_col1 {
#             background-color:  #89b2be;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row19_col0 {
#             background-color:  #bad2da;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row19_col1 {
#             background-color:  #f1b6ba;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row20_col0 {
#             background-color:  #efa8ad;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row20_col1 {
#             background-color:  #acc9d2;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row21_col0 {
#             background-color:  #eea5aa;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row21_col1 {
#             background-color:  #a9c7d0;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row22_col0 {
#             background-color:  #efacb1;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row22_col1 {
#             background-color:  #b0cbd4;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row23_col0 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row23_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_57b19b16_939d_11ea_b13e_0242ac1c0002row24_col0 {
#             background-color:  #f4c7cb;
#             color:  #000000;
#             font-size:  0pt;
#         }    #T_

# %%
f, ax = plt.subplots(figsize=(10, 8))
mask=np.zeros_like(dumm_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(dumm_corr, vmax = 1,
            cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, mask = mask,ax=ax)
