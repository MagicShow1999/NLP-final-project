# %%
import logging
import pandas as pd
import numpy as np
from numpy import random
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Snippet of the data
# Here we take a look of expert annotations data. We can see that a text is in "agreement throughout" doesn't always lead to its sentiment to be "positive". Also, we can see "constructive" texts mostly fall into our classifications of ERICs (that we'll be taking below) by looking at their sd_type.

# %%
df = pd.read_csv('./data/yahoodata/ydata-ynacc-v1_0_expert_annotations.tsv',sep='\t')
df.head()
# Out:
#      sdid  commentindex                                           headline  \
# 0   53971             2    Disneyland Worker Found Dead in Haunted Mansion
# 1   53971             0    Disneyland Worker Found Dead in Haunted Mansion
# 2   53971             1    Disneyland Worker Found Dead in Haunted Mansion
# 3  135929             0  This Old Navy Ad Featuring an Interracial Fami...
# 4  135929             1  This Old Navy Ad Featuring an Interracial Fami...
#
#                                                  url                  guid  \
# 0  http://www.cosmopolitan.com/lifestyle/news/a56...  rjrPtwH5oVVuQnEXX3hf
# 1  http://www.cosmopolitan.com/lifestyle/news/a56...  VaW6HEsuOFUAIBqjw1k~
# 2  http://www.cosmopolitan.com/lifestyle/news/a56...  uwQePj970KaMZuW3~9Q9
# 3  http://mic.com/articles/142323/this-old-navy-a...  fixyWJivQjEQtPLLVXsu
# 4  http://mic.com/articles/142323/this-old-navy-a...  _TDnK715vO5y0OzZz_n4
#
#                                            commentid   timestamp  thumbs-up  \
# 0  00003n000000000000000000000000-ed2ae6d0-32ac-4...  1459917444        NaN
# 1  1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...  1459879464        1.0
# 2  00002n000000000000000000000000-1c30b878-b717-4...  1459881644        NaN
# 3  1462203719963-3eeffb02-faae-4b51-9174-704c57e6...  1462203719       18.0
# 4  00002I000000000000000000000000-7ef2ac58-bd84-4...  1462204643        7.0
#
#    thumbs-down                                               text  \
# 0          NaN   These things happen , Every job has its dangers.
# 1          NaN  Sad to hear such a bad thing. Very dangerous j...
# 2          NaN  Yes..because too many houses in EU look like t...
# 3          3.0  I am frankly quite SICK of the phrase "shoved ...
# 4          2.0  Ya, I always wonder why the conservatives are ...
#
#                                             parentid constructiveclass  \
# 0  1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...      Constructive
# 1                                                NaN      Constructive
# 2  1459879464596-a3771c05-fd2e-4f44-a26a-23baec3b...      Constructive
# 3                                                NaN  Not constructive
# 4  1462203719963-3eeffb02-faae-4b51-9174-704c57e6...  Not constructive
#
#            sd_agreement               sd_type sentiment         tone  \
# 0                   NaN   Positive/respectful  negative          NaN
# 1                   NaN   Positive/respectful     mixed          NaN
# 2                   NaN   Positive/respectful   neutral  Informative
# 3  Agreement throughout  Off-topic/digression  negative         Mean
# 4  Agreement throughout  Off-topic/digression   neutral    Sarcastic
#
#               commentagreement                   topic  \
# 0  Disagreement with commenter  Off-topic with article
# 1                          NaN  Off-topic with article
# 2                          NaN  Off-topic with article
# 3                          NaN  Off-topic with article
# 4     Agreement with commenter  Off-topic with article
#
#                        intendedaudience  persuasiveness
# 0         Reply to a specific commenter  Not persuasive
# 1  Broadcast message / general audience  Not persuasive
# 2         Reply to a specific commenter  Not persuasive
# 3  Broadcast message / general audience      Persuasive
# 4         Reply to a specific commenter  Not persuasive

# %%
df[df['constructiveclass']=="Constructive"].groupby('sd_type').count()
# Out:
#                                                     sdid  commentindex  \
# sd_type
# Argumentative (back and forth)                      5930          5930
# Argumentative (back and forth),Flamewar (insult...   477           477
# Argumentative (back and forth),Flamewar (insult...    34            34
# Argumentative (back and forth),Flamewar (insult...     7             7
# Argumentative (back and forth),NA                     10            10
# Argumentative (back and forth),Off-topic/digres...   603           603
# Argumentative (back and forth),Off-topic/digres...    35            35
# Argumentative (back and forth),Off-topic/digres...     7             7
# Argumentative (back and forth),Off-topic/digres...     8             8
# Argumentative (back and forth),Off-topic/digres...    94            94
# Argumentative (back and forth),Off-topic/digres...    57            57
# Argumentative (back and forth),Off-topic/digres...     9             9
# Argumentative (back and forth),Personal stories      186           186
# Argumentative (back and forth),Positive/respectful   504           504
# Argumentative (back and forth),Positive/respect...    42            42
# Argumentative (back and forth),Snarky/humorous       192           192
# Argumentative (back and forth),Snarky/humorous,...    32            32
# Argumentative (back and forth),Snarky/humorous,...    88            88
# Argumentative (back and forth),Snarky/humorous,...    40            40
# Argumentative (back and forth),Snarky/humorous,...    47            47
# Argumentative (back and forth),Snarky/humorous,...    10            10
# Argumentative (back and forth),Snarky/humorous,...    18            18
# Argumentative (back and forth),Snarky/humorous,...    22            22
# Flamewar (insulting)                                  75            75
# Flamewar (insulting),Personal stories                  7             7
# Flamewar (insulting),Positive/respectful               9             9
# NA,Personal stories                                    3             3
# Off-topic/digression                                 451           451
# Off-topic/digression,Flamewar (insulting)             59            59
# Off-topic/digression,NA                                5             5
# Off-topic/digression,Personal stories                 25            25
# Off-topic/digression,Positive/respectful              88            88
# Off-topic/digression,Positive/respectful,Person...    14            14
# Personal stories                                     220           220
# Positive/respectful                                 1415          1415
# Positive/respectful,Personal stories                 287           287
# Snarky/humorous                                      284           284
# Snarky/humorous,Flamewar (insulting)                   4             4
# Snarky/humorous,Off-topic/digression                  29            29
# Snarky/humorous,Off-topic/digression,Positive/r...    10            10
# Snarky/humorous,Personal stories                      37            37
# Snarky/humorous,Positive/respectful                   59            59
# Snarky/humorous,Positive/respectful,Personal st...    11            11
#
#                                                     headline   url  guid  \
# sd_type
# Argumentative (back and forth)                          5930  5930  5930
# Argumentative (back and forth),Flamewar (insult...       477   477   477
# Argumentative (back and forth),Flamewar (insult...        34    34    34
# Argumentative (back and forth),Flamewar (insult...         7     7     7
# Argumentative (back and forth),NA                         10    10    10
# Argumentative (back and forth),Off-topic/digres...       603   603   603
# Argumentative (back and forth),Off-topic/digres...        35    35    35
# Argumentative (back and forth),Off-topic/digres...         7     7     7
# Argumentative (back and forth),Off-topic/digres...         8     8     8
# Argumentative (back and forth),Off-topic/digres...        94    94    94
# Argumentative (back and forth),Off-topic/digres...        57    57    57
# Argumentative (back and forth),Off-topic/digres...         9     9     9
# Argumentative (back and forth),Personal stories          186   186   186
# Argumentative (back and forth),Positive/respectful       504   504   504
# Argumentative (back and forth),Positive/respect...        42    42    42
# Argumentative (back and forth),Snarky/humorous           192   192   192
# Argumentative (back and forth),Snarky/humorous,...        32    32    32
# Argumentative (back and forth),Snarky/humorous,...        88    88    88
# Argumentative (back and forth),Snarky/humorous,...        40    40    40
# Argumentative (back and forth),Snarky/humorous,...        47    47    47
# Argumentative (back and forth),Snarky/humorous,...        10    10    10
# Argumentative (back and forth),Snarky/humorous,...        18    18    18
# Argumentative (back and forth),Snarky/humorous,...        22    22    22
# Flamewar (insulting)                                      75    75    75
# Flamewar (insulting),Personal stories                      7     7     7
# Flamewar (insulting),Positive/respectful                   9     9     9
# NA,Personal stories                                        3     3     3
# Off-topic/digression                                     451   451   451
# Off-topic/digression,Flamewar (insulting)                 59    59    59
# Off-topic/digression,NA                                    5     5     5
# Off-topic/digression,Personal stories                     25    25    25
# Off-topic/digression,Positive/respectful                  88    88    88
# Off-topic/digression,Positive/respectful,Person...        14    14    14
# Personal stories                                         220   220   220
# Positive/respectful                                     1415  1415  1415
# Positive/respectful,Personal stories                     287   287   287
# Snarky/humorous                                          284   284   284
# Snarky/humorous,Flamewar (insulting)                       4     4     4
# Snarky/humorous,Off-topic/digression                      29    29    29
# Snarky/humorous,Off-topic/digression,Positive/r...        10    10    10
# Snarky/humorous,Personal stories                          37    37    37
# Snarky/humorous,Positive/respectful                       59    59    59
# Snarky/humorous,Positive/respectful,Personal st...        11    11    11
#
#                                                     commentid  timestamp  \
# sd_type
# Argumentative (back and forth)                           5930       5930
# Argumentative (back and forth),Flamewar (insult...        477        477
# Argumentative (back and forth),Flamewar (insult...         34         34
# Argumentative (back and forth),Flamewar (insult...          7          7
# Argumentative (back and forth),NA                          10         10
# Argumentative (back and forth),Off-topic/digres...        603        603
# Argumentative (back and forth),Off-topic/digres...         35         35
# Argumentative (back and forth),Off-topic/digres...          7          7
# Argumentative (back and forth),Off-topic/digres...          8          8
# Argumentative (back and forth),Off-topic/digres...         94         94
# Argumentative (back and forth),Off-topic/digres...         57         57
# Argumentative (back and forth),Off-topic/digres...          9          9
# Argumentative (back and forth),Personal stories           186        186
# Argumentative (back and forth),Positive/respectful        504        504
# Argumentative (back and forth),Positive/respect...         42         42
# Argumentative (back and forth),Snarky/humorous            192        192
# Argumentative (back and forth),Snarky/humorous,...         32         32
# Argumentative (back and forth),Snarky/humorous,...         88         88
# Argumentative (back and forth),Snarky/humorous,...         40         40
# Argumentative (back and forth),Snarky/humorous,...         47         47
# Argumentative (back and forth),Snarky/humorous,...         10         10
# Argumentative (back and forth),Snarky/humorous,...         18         18
# Argumentative (back and forth),Snarky/humorous,...         22         22
# Flamewar (insulting)                                       75         75
# Flamewar (insulting),Personal stories                       7          7
# Flamewar (insulting),Positive/respectful                    9          9
# NA,Personal stories                                         3          3
# Off-topic/digression                                      451        451
# Off-topic/digression,Flamewar (insulting)                  59         59
# Off-topic/digression,NA                                     5          5
# Off-topic/digression,Personal stories                      25         25
# Off-topic/digression,Positive/respectful                   88         88
# Off-topic/digression,Positive/respectful,Person...         14         14
# Personal stories                                          220        220
# Positive/respectful                                      1415       1415
# Positive/respectful,Personal stories                      287        287
# Snarky/humorous                                           284        284
# Snarky/humorous,Flamewar (insulting)                        4          4
# Snarky/humorous,Off-topic/digression                       29         29
# Snarky/humorous,Off-topic/digression,Positive/r...         10         10
# Snarky/humorous,Personal stories                           37         37
# Snarky/humorous,Positive/respectful                        59         59
# Snarky/humorous,Positive/respectful,Personal st...         11         11
#
#                                                     thumbs-up  thumbs-down  \
# sd_type
# Argumentative (back and forth)                           4125         3870
# Argumentative (back and forth),Flamewar (insult...        317          323
# Argumentative (back and forth),Flamewar (insult...         26           22
# Argumentative (back and forth),Flamewar (insult...          7            7
# Argumentative (back and forth),NA                           9            5
# Argumentative (back and forth),Off-topic/digres...        405          346
# Argumentative (back and forth),Off-topic/digres...         26           27
# Argumentative (back and forth),Off-topic/digres...          5            3
# Argumentative (back and forth),Off-topic/digres...          6            1
# Argumentative (back and forth),Off-topic/digres...         56           62
# Argumentative (back and forth),Off-topic/digres...         45           36
# Argumentative (back and forth),Off-topic/digres...          8            6
# Argumentative (back and forth),Personal stories           132          107
# Argumentative (back and forth),Positive/respectful        325          281
# Argumentative (back and forth),Positive/respect...         36           28
# Argumentative (back and forth),Snarky/humorous            140          115
# Argumentative (back and forth),Snarky/humorous,...         21           19
# Argumentative (back and forth),Snarky/humorous,...         69           55
# Argumentative (back and forth),Snarky/humorous,...         28           25
# Argumentative (back and forth),Snarky/humorous,...         37           28
# Argumentative (back and forth),Snarky/humorous,...          8            7
# Argumentative (back and forth),Snarky/humorous,...         13           11
# Argumentative (back and forth),Snarky/humorous,...         19           21
# Flamewar (insulting)                                       49           56
# Flamewar (insulting),Personal stories                       6            5
# Flamewar (insulting),Positive/respectful                    7            4
# NA,Personal stories                                         1            1
# Off-topic/digression                                      336          284
# Off-topic/digression,Flamewar (insulting)                  42           38
# Off-topic/digression,NA                                     4            3
# Off-topic/digression,Personal stories                      19           15
# Off-topic/digression,Positive/respectful                   72           46
# Off-topic/digression,Positive/respectful,Person...         12            5
# Personal stories                                          147           99
# Positive/respectful                                      1002          680
# Positive/respectful,Personal stories                      204          114
# Snarky/humorous                                           229          154
# Snarky/humorous,Flamewar (insulting)                        3            3
# Snarky/humorous,Off-topic/digression                       23            9
# Snarky/humorous,Off-topic/digression,Positive/r...          4            6
# Snarky/humorous,Personal stories                           29           25
# Snarky/humorous,Positive/respectful                        39           26
# Snarky/humorous,Positive/respectful,Personal st...          9            4
#
#                                                     text  parentid  \
# sd_type
# Argumentative (back and forth)                      5930      5097
# Argumentative (back and forth),Flamewar (insult...   477       414
# Argumentative (back and forth),Flamewar (insult...    34        31
# Argumentative (back and forth),Flamewar (insult...     7         6
# Argumentative (back and forth),NA                     10         8
# Argumentative (back and forth),Off-topic/digres...   603       526
# Argumentative (back and forth),Off-topic/digres...    35        32
# Argumentative (back and forth),Off-topic/digres...     7         6
# Argumentative (back and forth),Off-topic/digres...     8         7
# Argumentative (back and forth),Off-topic/digres...    94        84
# Argumentative (back and forth),Off-topic/digres...    57        52
# Argumentative (back and forth),Off-topic/digres...     9         8
# Argumentative (back and forth),Personal stories      186       163
# Argumentative (back and forth),Positive/respectful   504       432
# Argumentative (back and forth),Positive/respect...    42        37
# Argumentative (back and forth),Snarky/humorous       192       165
# Argumentative (back and forth),Snarky/humorous,...    32        29
# Argumentative (back and forth),Snarky/humorous,...    88        77
# Argumentative (back and forth),Snarky/humorous,...    40        36
# Argumentative (back and forth),Snarky/humorous,...    47        43
# Argumentative (back and forth),Snarky/humorous,...    10         9
# Argumentative (back and forth),Snarky/humorous,...    18        16
# Argumentative (back and forth),Snarky/humorous,...    22        19
# Flamewar (insulting)                                  75        63
# Flamewar (insulting),Personal stories                  7         6
# Flamewar (insulting),Positive/respectful               9         7
# NA,Personal stories                                    3         2
# Off-topic/digression                                 451       381
# Off-topic/digression,Flamewar (insulting)             59        52
# Off-topic/digression,NA                                5         4
# Off-topic/digression,Personal stories                 25        21
# Off-topic/digression,Positive/respectful              88        75
# Off-topic/digression,Positive/respectful,Person...    14        13
# Personal stories                                     220       181
# Positive/respectful                                 1415      1173
# Positive/respectful,Personal stories                 287       247
# Snarky/humorous                                      284       234
# Snarky/humorous,Flamewar (insulting)                   4         3
# Snarky/humorous,Off-topic/digression                  29        25
# Snarky/humorous,Off-topic/digression,Positive/r...    10         9
# Snarky/humorous,Personal stories                      37        32
# Snarky/humorous,Positive/respectful                   59        47
# Snarky/humorous,Positive/respectful,Personal st...    11         9
#
#                                                     constructiveclass  \
# sd_type
# Argumentative (back and forth)                                   5930
# Argumentative (back and forth),Flamewar (insult...                477
# Argumentative (back and forth),Flamewar (insult...                 34
# Argumentative (back and forth),Flamewar (insult...                  7
# Argumentative (back and forth),NA                                  10
# Argumentative (back and forth),Off-topic/digres...                603
# Argumentative (back and forth),Off-topic/digres...                 35
# Argumentative (back and forth),Off-topic/digres...                  7
# Argumentative (back and forth),Off-topic/digres...                  8
# Argumentative (back and forth),Off-topic/digres...                 94
# Argumentative (back and forth),Off-topic/digres...                 57
# Argumentative (back and forth),Off-topic/digres...                  9
# Argumentative (back and forth),Personal stories                   186
# Argumentative (back and forth),Positive/respectful                504
# Argumentative (back and forth),Positive/respect...                 42
# Argumentative (back and forth),Snarky/humorous                    192
# Argumentative (back and forth),Snarky/humorous,...                 32
# Argumentative (back and forth),Snarky/humorous,...                 88
# Argumentative (back and forth),Snarky/humorous,...                 40
# Argumentative (back and forth),Snarky/humorous,...                 47
# Argumentative (back and forth),Snarky/humorous,...                 10
# Argumentative (back and forth),Snarky/humorous,...                 18
# Argumentative (back and forth),Snarky/humorous,...                 22
# Flamewar (insulting)                                               75
# Flamewar (insulting),Personal stories                               7
# Flamewar (insulting),Positive/respectful                            9
# NA,Personal stories                                                 3
# Off-topic/digression                                              451
# Off-topic/digression,Flamewar (insulting)                          59
# Off-topic/digression,NA                                             5
# Off-topic/digression,Personal stories                              25
# Off-topic/digression,Positive/respectful                           88
# Off-topic/digression,Positive/respectful,Person...                 14
# Personal stories                                                  220
# Positive/respectful                                              1415
# Positive/respectful,Personal stories                              287
# Snarky/humorous                                                   284
# Snarky/humorous,Flamewar (insulting)                                4
# Snarky/humorous,Off-topic/digression                               29
# Snarky/humorous,Off-topic/digression,Positive/r...                 10
# Snarky/humorous,Personal stories                                   37
# Snarky/humorous,Positive/respectful                                59
# Snarky/humorous,Positive/respectful,Personal st...                 11
#
#                                                     sd_agreement  sentiment  \
# sd_type
# Argumentative (back and forth)                              5712       5900
# Argumentative (back and forth),Flamewar (insult...           477        475
# Argumentative (back and forth),Flamewar (insult...            20         34
# Argumentative (back and forth),Flamewar (insult...             7          7
# Argumentative (back and forth),NA                              6          9
# Argumentative (back and forth),Off-topic/digres...           491        598
# Argumentative (back and forth),Off-topic/digres...            35         35
# Argumentative (back and forth),Off-topic/digres...             7          7
# Argumentative (back and forth),Off-topic/digres...             8          8
# Argumentative (back and forth),Off-topic/digres...            73         93
# Argumentative (back and forth),Off-topic/digres...            42         57
# Argumentative (back and forth),Off-topic/digres...             9          9
# Argumentative (back and forth),Personal stories              174        185
# Argumentative (back and forth),Positive/respectful           488        504
# Argumentative (back and forth),Positive/respect...            42         41
# Argumentative (back and forth),Snarky/humorous               173        190
# Argumentative (back and forth),Snarky/humorous,...            32         32
# Argumentative (back and forth),Snarky/humorous,...            48         88
# Argumentative (back and forth),Snarky/humorous,...            27         40
# Argumentative (back and forth),Snarky/humorous,...            47         47
# Argumentative (back and forth),Snarky/humorous,...            10         10
# Argumentative (back and forth),Snarky/humorous,...            18         18
# Argumentative (back and forth),Snarky/humorous,...            22         22
# Flamewar (insulting)                                          75         75
# Flamewar (insulting),Personal stories                          7          7
# Flamewar (insulting),Positive/respectful                       5          9
# NA,Personal stories                                            0          3
# Off-topic/digression                                         369        447
# Off-topic/digression,Flamewar (insulting)                     49         59
# Off-topic/digression,NA                                        0          5
# Off-topic/digression,Personal stories                         20         25
# Off-topic/digression,Positive/respectful                      55         83
# Off-topic/digression,Positive/respectful,Person...            14         14
# Personal stories                                             168        218
# Positive/respectful                                         1147       1401
# Positive/respectful,Personal stories                         226        281
# Snarky/humorous                                              207        282
# Snarky/humorous,Flamewar (insulting)                           4          4
# Snarky/humorous,Off-topic/digression                          29         29
# Snarky/humorous,Off-topic/digression,Positive/r...            10          8
# Snarky/humorous,Personal stories                              37         37
# Snarky/humorous,Positive/respectful                           54         59
# Snarky/humorous,Positive/respectful,Personal st...             0         11
#
#                                                     tone  commentagreement  \
# sd_type
# Argumentative (back and forth)                      5015              4339
# Argumentative (back and forth),Flamewar (insult...   443               361
# Argumentative (back and forth),Flamewar (insult...    31                30
# Argumentative (back and forth),Flamewar (insult...     6                 2
# Argumentative (back and forth),NA                      9                 7
# Argumentative (back and forth),Off-topic/digres...   506               479
# Argumentative (back and forth),Off-topic/digres...    34                22
# Argumentative (back and forth),Off-topic/digres...     7                 5
# Argumentative (back and forth),Off-topic/digres...     8                 7
# Argumentative (back and forth),Off-topic/digres...    85                72
# Argumentative (back and forth),Off-topic/digres...    52                50
# Argumentative (back and forth),Off-topic/digres...     8                 7
# Argumentative (back and forth),Personal stories      167               151
# Argumentative (back and forth),Positive/respectful   458               386
# Argumentative (back and forth),Positive/respect...    42                37
# Argumentative (back and forth),Snarky/humorous       173               159
# Argumentative (back and forth),Snarky/humorous,...    32                25
# Argumentative (back and forth),Snarky/humorous,...    81                70
# Argumentative (back and forth),Snarky/humorous,...    37                34
# Argumentative (back and forth),Snarky/humorous,...    45                43
# Argumentative (back and forth),Snarky/humorous,...    10                10
# Argumentative (back and forth),Snarky/humorous,...    18                16
# Argumentative (back and forth),Snarky/humorous,...    21                19
# Flamewar (insulting)                                  68                55
# Flamewar (insulting),Personal stories                  5                 1
# Flamewar (insulting),Positive/respectful               8                 1
# NA,Personal stories                                    2                 2
# Off-topic/digression                                 329               281
# Off-topic/digression,Flamewar (insulting)             55                41
# Off-topic/digression,NA                                1                 0
# Off-topic/digression,Personal stories                 22                17
# Off-topic/digression,Positive/respectful              39                53
# Off-topic/digression,Positive/respectful,Person...    13                13
# Personal stories                                     161               165
# Positive/respectful                                 1035               923
# Positive/respectful,Personal stories                 216               196
# Snarky/humorous                                      248               198
# Snarky/humorous,Flamewar (insulting)                   4                 3
# Snarky/humorous,Off-topic/digression                  21                25
# Snarky/humorous,Off-topic/digression,Positive/r...     2                 8
# Snarky/humorous,Personal stories                      32                31
# Snarky/humorous,Positive/respectful                   51                35
# Snarky/humorous,Positive/respectful,Personal st...    11                 9
#
#                                                     topic  intendedaudience  \
# sd_type
# Argumentative (back and forth)                       1895              5892
# Argumentative (back and forth),Flamewar (insult...    113               472
# Argumentative (back and forth),Flamewar (insult...      6                34
# Argumentative (back and forth),Flamewar (insult...      0                 7
# Argumentative (back and forth),NA                       2                 9
# Argumentative (back and forth),Off-topic/digres...    443               598
# Argumentative (back and forth),Off-topic/digres...     12                35
# Argumentative (back and forth),Off-topic/digres...      2                 7
# Argumentative (back and forth),Off-topic/digres...      4                 8
# Argumentative (back and forth),Off-topic/digres...     64                94
# Argumentative (back and forth),Off-topic/digres...     32                57
# Argumentative (back and forth),Off-topic/digres...      5                 9
# Argumentative (back and forth),Personal stories        81               185
# Argumentative (back and forth),Positive/respectful     92               503
# Argumentative (back and forth),Positive/respect...     15                42
# Argumentative (back and forth),Snarky/humorous         66               192
# Argumentative (back and forth),Snarky/humorous,...      8                32
# Argumentative (back and forth),Snarky/humorous,...     51                86
# Argumentative (back and forth),Snarky/humorous,...     28                40
# Argumentative (back and forth),Snarky/humorous,...     34                47
# Argumentative (back and forth),Snarky/humorous,...      9                10
# Argumentative (back and forth),Snarky/humorous,...      8                18
# Argumentative (back and forth),Snarky/humorous,...      9                22
# Flamewar (insulting)                                   45                75
# Flamewar (insulting),Personal stories                   1                 7
# Flamewar (insulting),Positive/respectful                0                 9
# NA,Personal stories                                     1                 3
# Off-topic/digression                                  360               446
# Off-topic/digression,Flamewar (insulting)              42                58
# Off-topic/digression,NA                                 5                 5
# Off-topic/digression,Personal stories                  23                25
# Off-topic/digression,Positive/respectful               63                85
# Off-topic/digression,Positive/respectful,Person...      3                14
# Personal stories                                      164               219
# Positive/respectful                                   435              1397
# Positive/respectful,Personal stories                  134               285
# Snarky/humorous                                       117               283
# Snarky/humorous,Flamewar (insulting)                    0                 4
# Snarky/humorous,Off-topic/digression                   24                29
# Snarky/humorous,Off-topic/digression,Positive/r...     10                 8
# Snarky/humorous,Personal stories                       23                37
# Snarky/humorous,Positive/respectful                    13                58
# Snarky/humorous,Positive/respectful,Personal st...      7                11
#
#                                                     persuasiveness
# sd_type
# Argumentative (back and forth)                                5840
# Argumentative (back and forth),Flamewar (insult...             472
# Argumentative (back and forth),Flamewar (insult...              30
# Argumentative (back and forth),Flamewar (insult...               7
# Argumentative (back and forth),NA                               10
# Argumentative (back and forth),Off-topic/digres...             569
# Argumentative (back and forth),Off-topic/digres...              35
# Argumentative (back and forth),Off-topic/digres...               7
# Argumentative (back and forth),Off-topic/digres...               8
# Argumentative (back and forth),Off-topic/digres...              87
# Argumentative (back and forth),Off-topic/digres...              47
# Argumentative (back and forth),Off-topic/digres...               9
# Argumentative (back and forth),Personal stories                182
# Argumentative (back and forth),Positive/respectful             501
# Argumentative (back and forth),Positive/respect...              42
# Argumentative (back and forth),Snarky/humorous                 185
# Argumentative (back and forth),Snarky/humorous,...              32
# Argumentative (back and forth),Snarky/humorous,...              73
# Argumentative (back and forth),Snarky/humorous,...              33
# Argumentative (back and forth),Snarky/humorous,...              47
# Argumentative (back and forth),Snarky/humorous,...              10
# Argumentative (back and forth),Snarky/humorous,...              18
# Argumentative (back and forth),Snarky/humorous,...              22
# Flamewar (insulting)                                            68
# Flamewar (insulting),Personal stories                            7
# Flamewar (insulting),Positive/respectful                         9
# NA,Personal stories                                              3
# Off-topic/digression                                           414
# Off-topic/digression,Flamewar (insulting)                       57
# Off-topic/digression,NA                                          5
# Off-topic/digression,Personal stories                           25
# Off-topic/digression,Positive/respectful                        71
# Off-topic/digression,Positive/respectful,Person...              14
# Personal stories                                               216
# Positive/respectful                                           1347
# Positive/respectful,Personal stories                           265
# Snarky/humorous                                                272
# Snarky/humorous,Flamewar (insulting)                             4
# Snarky/humorous,Off-topic/digression                            28
# Snarky/humorous,Off-topic/digression,Positive/r...              10
# Snarky/humorous,Personal stories                                37
# Snarky/humorous,Positive/respectful                             56
# Snarky/humorous,Positive/respectful,Personal st...              10

# %% [markdown]
# ## Definition of ERICs
# ERICs are characterized by argumentative, respectful exchanges containing persuasive, informative, and/or sympathetic comments. They tend to stay on topic with the original article and not to contain funny, mean, or sarcastic comments. We found differences between the distribution of annotations made by trained and untrained anno- tators, but high levels of agreement within each group, suggesting that crowdsourcing annotations for this task is reliable.
#
# Now, we select the columns related to ERICs and mainly look at these.

# %%
df = df[['text','constructiveclass','sd_type','sentiment','persuasiveness','tone']]
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

df.head()
# Out:
#                                                 text constructiveclass  \
# 0  Yes..because too many houses in EU look like t...      Constructive
# 1  I am frankly quite SICK of the phrase "shoved ...  Not constructive
# 2  Ya, I always wonder why the conservatives are ...  Not constructive
# 3  They are also places where you are supposed no...  Not constructive
# 4  Stop trying to make sense, it only confuses pe...  Not constructive
#
#                           sd_type sentiment  persuasiveness         tone
# 0             Positive/respectful   neutral  Not persuasive  Informative
# 1            Off-topic/digression  negative      Persuasive         Mean
# 2            Off-topic/digression   neutral  Not persuasive    Sarcastic
# 3  Argumentative (back and forth)   neutral      Persuasive    Sarcastic
# 4  Argumentative (back and forth)  negative      Persuasive         Mean

# %% [markdown]
# ## Classifying ERIC by certain fields
# ---
# Next, we try to classify the ERIC by observing the certain attributes of each text. We are not selecting all columns because for instance, the sd_type columns contain more than one attribute of the certain text because this column represents the properties of the whole thread of dicussions and so every text belonged to that thread is labeled the same tag even if that comment does not correspond with the attribute it is labeled. Also the column 'topic' mostly contains 'off-topic' comments which seems to be strange so we are not taking this column into consideration. Thus, we ultimately decide to choose 'constructiveclass', 'persuasiveness', 'tone' as our standard to classify ERICs. An ERIC should have a constructive label, persuasive label and an Informative tone.

# %% [markdown]
# ### Add the new column 'ERIC' to the data

# %%
df['ERIC'] = 0

df.loc[(df['constructiveclass'] == 'Constructive') 
       & (df['persuasiveness'] == 'Persuasive')
       &(df['tone'] == 'Informative'),"ERIC"] = 1

# %%
df[df['ERIC'] == 1]
# Out:
#                                                     text constructiveclass  \
# 8      I know this was probably the best thing that e...      Constructive
# 9      Ghrelin is produced by your fat cells. You can...      Constructive
# 30     I believe they are eaten in Venezuela? It's a ...      Constructive
# 37     HF and You've got to be kidding me.... Nelson ...      Constructive
# 39     So Ed - 12,000 - that's still FOUR TIMES more ...      Constructive
# ...                                                  ...               ...
# 17415  alex - Sorry, but you are wrong and show an in...      Constructive
# 17428  When Nate Silver has Ms Clinton's chance of wi...      Constructive
# 17443  If any politician in my lifetime fits the defi...      Constructive
# 17451  As a naturally aspirated Camaro SS owner, I ra...      Constructive
# 17558  steve do not forget nafta was a G.H. Bush nego...      Constructive
#
#                               sd_type sentiment persuasiveness         tone  \
# 8      Argumentative (back and forth)   neutral     Persuasive  Informative
# 9                 Positive/respectful   neutral     Persuasive  Informative
# 30                Positive/respectful   neutral     Persuasive  Informative
# 37     Argumentative (back and forth)   neutral     Persuasive  Informative
# 39     Argumentative (back and forth)  negative     Persuasive  Informative
# ...                               ...       ...            ...          ...
# 17415                 Snarky/humorous     mixed     Persuasive  Informative
# 17428                 Snarky/humorous  negative     Persuasive  Informative
# 17443  Argumentative (back and forth)  negative     Persuasive  Informative
# 17451             Positive/respectful   neutral     Persuasive  Informative
# 17558  Argumentative (back and forth)   neutral     Persuasive  Informative
#
#        ERIC
# 8         1
# 9         1
# 30        1
# 37        1
# 39        1
# ...     ...
# 17415     1
# 17428     1
# 17443     1
# 17451     1
# 17558     1
#
# [967 rows x 7 columns]

# %% [markdown]
# ### Logistic Regression

# %%
#first we divide the data into training and testing sets
training_set, test_set = train_test_split(df, test_size=0.3, random_state=42)


#then preprocess the text with the rule of Bag of Words 
def words_in_texts(words, texts):
    '''
    Inputs:
        words (list-like): words to find
        texts (Series): strings to search in
    
    Output:
        NumPy array of 0s and 1s with shape (n, p) where n is the
        number of texts and p is the number of words.
    '''
    nested_arr = []
    for text in texts:
        arr = []
        for word in words:
            if word in text:
                arr.append(1)
            else:
                arr.append(0)
        nested_arr.append(arr)
    return nested_arr

# %%
some_words = ['please','thanks','suggest','advice','note']
X_train = words_in_texts(some_words,training_set.text)
Y_train = np.asarray(training_set.ERIC)

# %%
model = LogisticRegression()
model.fit(X_train,Y_train)
training_accuracy = model.score(X_train, Y_train)

print('Logistic Regression training_accuracy:',training_accuracy)
# Y_train_hat = model.predict(Y_train)
# Out:
# Logistic Regression training_accuracy: 0.9448857189171664

# %% [markdown]
# ### Naive Bayes

# %%
X_train = training_set.text
Y_train = training_set.ERIC

#this time use tf-idf and vectorizer to preprocess text and use naive bayes as the model
nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(X_train, Y_train)


X_test = test_set.text
Y_test = test_set.ERIC
y_pred = nb.predict(X_test)

print('Naive Bayes accuracy %s' % accuracy_score(y_pred, Y_test))
# Out:
# Naive Bayes accuracy 0.9457261724659607

# %% [markdown]
# ## Sentiment Field Training and Evaluation
# ---

# %%
df['sentiment'].value_counts()
# Out:
# negative    10262
# neutral      3443
# mixed        2737
# positive     1184
# Name: sentiment, dtype: int64

# %% [markdown]
# Let's firstly take a look of how well we can predict the sentiment of a text.

# %%
sentiments = df['sentiment'].unique()

# %%
data = df[['text','sentiment']]

# %%
neg_data = data.groupby('sentiment').get_group('negative')
mix_data = data.groupby('sentiment').get_group('mixed')
neu_data = data.groupby('sentiment').get_group('neutral')
pos_data = data.groupby('sentiment').get_group('positive')
neg_data
# Out:
#                                                     text sentiment
# 1      I am frankly quite SICK of the phrase "shoved ...  negative
# 4      Stop trying to make sense, it only confuses pe...  negative
# 7      Look up teacher "Michelle Yeh" guys. Would've ...  negative
# 10                        George H. Smith is/was a fool.  negative
# 11                        George H. smith is a damn fool  negative
# ...                                                  ...       ...
# 17621  Thanks for providing oil corporation figures, ...  negative
# 17622  @USERNAME - I hope Miami doesn't drown. And I ...  negative
# 17623      Brazilian fans suck as much as their country.  negative
# 17624  Brazilian fans are just like fans of any other...  negative
# 17625                  You sound like a stupid brazilian  negative
#
# [10262 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = [np.array([],dtype='str'), np.array([],dtype='str'),np.array([],dtype='str'),np.array([],dtype='str')]

# %% [markdown]
# Since negative sentiment texts are much more than other types of texts, we can't directly do train_test_split (because sometimes we may fail to choose from all 4 labels and resulting error in classification_report). We need to train_test_split from each type of sentiment and combine the training/test data/labels.

# %%
for item in [neg_data, mix_data, neu_data, pos_data]:
    X = item.text.to_numpy()
    y = item.sentiment.to_numpy()
    X_train_loc, X_test_loc, y_train_loc, y_test_loc = train_test_split(X, y, test_size=0.3, random_state = 42)
    X_train = np.concatenate((X_train_loc, X_train))
    X_test = np.concatenate((X_test_loc, X_test))
    y_train = np.concatenate((y_train_loc, y_train))
    y_test = np.concatenate((y_test_loc, y_test))

# %%
# sanity check for the train & test data
print(len(neg_data)+len(mix_data)+len(neu_data)+len(pos_data))
print(len(X_train)+len(X_test))
# Out:
# 20749
# 20749

# %%
nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(X_train, y_train)

from sklearn.metrics import classification_report
y_pred = nb.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred, target_names=sentiments))
# Out:
# accuracy 0.5357314918901558
#               precision    recall  f1-score   support
#
#     negative       0.67      0.00      0.00      1009
#        mixed       0.53      0.99      0.69      3264
#      neutral       0.57      0.07      0.12      1532
#     positive       0.67      0.01      0.02       422
#
#     accuracy                           0.54      6227
#    macro avg       0.61      0.27      0.21      6227
# weighted avg       0.57      0.54      0.40      6227
